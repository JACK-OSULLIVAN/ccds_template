# %%
import pandas_datareader.data as web
import pandas as pd
import requests
import matplotlib
import datetime as dt

# %%
df = pd.read_csv("../data/raw/OSullivan_Capital.csv")
df.head()
# Out:
#   ASX Listed Equities               Unnamed: 1  \
# 0               Stock  Proportion of Portfolio
# 1                 A2M                    0.58%
# 2                 ART                    0.07%
# 3                ASIA                    2.10%
# 4                 ASN                    0.02%
#
#                             Unnamed: 2
# 0                                Notes
# 1                                  NaN
# 2                                  NaN
# 3  - ETF composed of Asian tech stocks
# 4                                  NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ASX Listed Equities  57 non-null     object
#  1   Unnamed: 1           56 non-null     object
#  2   Unnamed: 2           10 non-null     object
# dtypes: object(3)
# memory usage: 1.5+ KB

# %%
start = dt.datetime(2014,1,1)
end = dt.datetime.now()

# %%
us_tickers = ["ACN", "AMZN", "BA", "CRM", "ESPR", "EXAI", "ICLN", "INDA", "INTC", "ISRG", "KLAC", "KLIC", "LICY", "LMT", "MDB", "MSFT", "NVDA", "PLTR", "SAP", "TEAM", "VGT"]

# %%
# stock_df = pd.DataFrame()
# for ticker in us_tickers:
#     df2 = web.DataReader(ticker, "yahoo", start, end)
#     df[ticker] = df2["Adj Close"]

# %%
# stock_df = web.DataReader(us_stock_list, 'yahoo', start, end)

# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()
y_symbols = us_tickers
from datetime import datetime
startdate = datetime(2015,1,1)
enddate = datetime.now()
data = pdr.get_data_yahoo(y_symbols, start=startdate, end=enddate)
# Out:
# [*********************100%%**********************]  21 of 21 completed

# %%
data.tail()
# Out:
# Price        Adj Close                                                         \
# Ticker             ACN        AMZN          BA         CRM  ESPR  EXAI   ICLN
# Date
# 2024-05-28  297.730011  182.149994  175.080002  269.829987  2.10  4.76  15.08
# 2024-05-29  293.769989  182.020004  171.649994  271.619995  2.17  4.67  14.83
# 2024-05-30  284.799988  179.320007  172.750000  218.009995  2.29  4.94  15.04
# 2024-05-31  282.290009  176.440002  177.610001  234.440002  2.16  5.30  14.97
# 2024-06-03  281.760010  178.339996  184.570007  236.619995  2.24  5.42  15.08
#
# Price                                         ...  Volume                     \
# Ticker           INDA       INTC        ISRG  ...    KLIC      LICY      LMT
# Date                                          ...
# 2024-05-28  53.560001  31.059999  401.029999  ...  287500  649675.0  1150400
# 2024-05-29  53.279999  30.129999  398.399994  ...  363000  468933.0  1268000
# ...

# %%
import numpy as np
return1 = np.log(data/data.shift())

# %%
return1.head()
# Out:
# Price      Adj Close                                                         \
# Ticker           ACN      AMZN        BA       CRM      ESPR EXAI      ICLN
# Date
# 2015-01-02       NaN       NaN       NaN       NaN       NaN  NaN       NaN
# 2015-01-05 -0.017029 -0.020731 -0.006950 -0.018227  0.069332  NaN -0.021773
# 2015-01-06 -0.007239 -0.023098 -0.011848 -0.016816 -0.018731  NaN -0.002099
# 2015-01-07  0.020772  0.010544  0.015406 -0.004731  0.081868  NaN  0.009409
# 2015-01-08  0.015134  0.006813  0.017528  0.028742  0.018731  NaN  0.023652
#
# Price                                     ...    Volume                     \
# Ticker          INDA      INTC      ISRG  ...      KLIC LICY       LMT MDB
# Date                                      ...
# 2015-01-02       NaN       NaN       NaN  ...       NaN  NaN       NaN NaN
# 2015-01-05 -0.016255 -0.011340 -0.021541  ...  0.623253  NaN  0.512620 NaN
# 2015-01-06 -0.030907 -0.018813  0.010482  ... -0.107016  NaN -0.222447 NaN
# ...

# %%
return1.dropna(inplace=True)

# %%
return1.head()
# Out:
# Price      Adj Close                                                    \
# Ticker           ACN      AMZN        BA       CRM      ESPR      EXAI
# Date
# 2021-10-04 -0.016668 -0.028885 -0.009827 -0.016114 -0.016068 -0.070312
# 2021-10-05  0.017468  0.009740  0.002811  0.003354 -0.106972 -0.102462
# 2021-10-06  0.000215  0.012652  0.002537  0.012796 -0.035735 -0.022622
# 2021-10-07  0.003254  0.012315  0.006601 -0.002510 -0.001969  0.004923
# 2021-10-08 -0.003254 -0.004191 -0.000397 -0.007677  0.008828  0.071074
#
# Price                                               ...    Volume            \
# Ticker          ICLN      INDA      INTC      ISRG  ...      KLIC      LICY
# Date                                                ...
# 2021-10-04 -0.026532 -0.004895 -0.007267 -0.039399  ...  0.574277 -0.066866
# 2021-10-05  0.001885  0.011789  0.008937  0.020106  ... -0.001575  0.223842
# 2021-10-06  0.002351 -0.009746  0.000556  0.014647  ... -0.391597  1.716508
# ...

# %%
Er = np.array(return1.describe().loc['mean'])
std = np.array(return1.describe().loc['std'])
var = std**2

# %%
varcover1 = return1.cov()
varcover1
# Out:
# Price            Adj Close                                              \
# Ticker                 ACN      AMZN        BA       CRM          ESPR
# Price     Ticker
# Adj Close ACN     0.000296  0.000232  0.000150  0.000232  1.038844e-04
#           AMZN    0.000232  0.000600  0.000219  0.000351  1.447173e-04
#           BA      0.000150  0.000219  0.000572  0.000201  1.893487e-04
#           CRM     0.000232  0.000351  0.000201  0.000632  2.189576e-04
#           ESPR    0.000104  0.000145  0.000189  0.000219  4.443871e-03
# ...                    ...       ...       ...       ...           ...
# Volume    NVDA    0.000077 -0.000096 -0.000233  0.000319 -5.597660e-04
#           PLTR   -0.000113  0.000024 -0.000389 -0.000335 -4.191447e-07
#           SAP    -0.000574 -0.000580 -0.000442 -0.000726 -6.193346e-04
#           TEAM   -0.000065 -0.000124 -0.000470 -0.000319 -5.153038e-04
#           VGT    -0.000767 -0.000821 -0.002099 -0.000304 -1.713889e-03
#
# ...
